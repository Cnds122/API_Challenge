# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create random lat and lon
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add to list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#list
cities = []

#nearest city
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
#count.
len(cities)
# Out:
# 760

# %%
import requests

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#empty list
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#counters.
record_count = 1
set_count = 1

# Loop
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    
# Loopx2
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Endpoint
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# API request
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"] 
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | ossora
# Processing Record 2 of Set 16 | puerto ayora
# Processing Record 3 of Set 16 | castro
# Processing Record 4 of Set 16 | yellowknife
# Processing Record 5 of Set 16 | biltine
# Processing Record 6 of Set 16 | fortuna
# Processing Record 7 of Set 16 | igunga
# Processing Record 8 of Set 16 | vaini
# Processing Record 9 of Set 16 | keti bandar
# Processing Record 10 of Set 16 | gravdal
# Processing Record 11 of Set 16 | thompson
# Processing Record 12 of Set 16 | malakal
# Processing Record 13 of Set 16 | ushuaia
# Processing Record 14 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 16 | oxbow
# Processing Record 16 of Set 16 | flinders
# Processing Record 17 of Set 16 | butaritari
# Processing Record 18 of Set 16 | saint-philippe
# Processing Record 19 of Set 16 | anadyr
# Processing Record 20 of Set 16 | leningradskiy
# Processing Record 21 of Set 16 | albany
# Processing Record 22 of Set 16 | port elizabeth
# Processing Record 23 of Set 16 | busselton
# Processing Record 24 of Set 16 | bredasdorp
# Processing Record 25 of Set 16 | sao filipe
# Processing Record 26 of Set 16 | port lincoln
# Processing Record 27 of Set 16 | teya
# Processing Record 28 of Set 16 | jamestown
# Processing Record 29 of Set 16 | kasimov
# Processing Record 30 of Set 16 | mahebourg
# Processing Record 31 of Set 16 | lebu
# Processing Record 32 of Set 16 | bluff
# Processing Record 33 of Set 16 | jacmel
# Processing Record 34 of Set 16 | urfa
# City not found. Skipping...
# Processing Record 35 of Set 16 | port alfred
# Processing Record 36 of Set 16 | colares
# Processing Record 37 of Set 16 | pangnirtung
# Processing Record 38 of Set 16 | atambua
# Processing Record 39 of Set 16 | ribeira grande
# Processing Record 40 of Set 16 | chokurdakh
# Processing Record 41 of Set 16 | kapaa
# Processing Record 42 of Set 16 | los llanos de aridane
# Processing Record 43 of Set 16 | provideniya
# Processing Record 44 of Set 16 | imbituba
# Processing Record 45 of Set 16 | mataura
# Processing Record 46 of Set 16 | iskateley
# Processing Record 47 of Set 16 | rio grande
# Processing Record 48 of Set 16 | roma
# Processing Record 49 of Set 16 | martapura
# Processing Record 50 of Set 16 | cape town
# Processing Record 1 of Set 17 | sabaudia
# Processing Record 2 of Set 17 | tiksi
# Processing Record 3 of Set 17 | pevek
# Processing Record 4 of Set 17 | hobart
# Processing Record 5 of Set 17 | bria
# Processing Record 6 of Set 17 | ancud
# Processing Record 7 of Set 17 | kaitangata
# Processing Record 8 of Set 17 | sao joao da barra
# Processing Record 9 of Set 17 | karpogory
# Processing Record 10 of Set 17 | norfolk
# Processing Record 11 of Set 17 | kavieng
# Processing Record 12 of Set 17 | westport
# Processing Record 13 of Set 17 | rikitea
# Processing Record 14 of Set 17 | amapa
# Processing Record 15 of Set 17 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 17 | palmer
# Processing Record 17 of Set 17 | itarema
# Processing Record 18 of Set 17 | punta arenas
# Processing Record 19 of Set 17 | geraldton
# Processing Record 20 of Set 17 | poum
# Processing Record 21 of Set 17 | rabo de peixe
# Processing Record 22 of Set 17 | hilo
# Processing Record 23 of Set 17 | saint george
# Processing Record 24 of Set 17 | ojinaga
# Processing Record 25 of Set 17 | longyearbyen
# Processing Record 26 of Set 17 | atuona
# Processing Record 27 of Set 17 | avarua
# Processing Record 28 of Set 17 | qaanaaq
# Processing Record 29 of Set 17 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 17 | severo-kurilsk
# Processing Record 31 of Set 17 | slavyanka
# Processing Record 32 of Set 17 | carnarvon
# Processing Record 33 of Set 17 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 17 | amnat charoen
# Processing Record 35 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 17 | bud
# Processing Record 37 of Set 17 | taltal
# Processing Record 38 of Set 17 | yunhe
# Processing Record 39 of Set 17 | pisco
# Processing Record 40 of Set 17 | mackay
# Processing Record 41 of Set 17 | vestmanna
# Processing Record 42 of Set 17 | labranzagrande
# Processing Record 43 of Set 17 | mahasamund
# Processing Record 44 of Set 17 | novyy yarychiv
# Processing Record 45 of Set 17 | north battleford
# Processing Record 46 of Set 17 | birao
# Processing Record 47 of Set 17 | mar del plata
# Processing Record 48 of Set 17 | cockburn town
# Processing Record 49 of Set 17 | naranjito
# Processing Record 50 of Set 17 | khatanga
# Processing Record 1 of Set 18 | cabo san lucas
# Processing Record 2 of Set 18 | mehamn
# Processing Record 3 of Set 18 | saint-joseph
# Processing Record 4 of Set 18 | faanui
# Processing Record 5 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 18 | tilichiki
# Processing Record 7 of Set 18 | victoria
# Processing Record 8 of Set 18 | shu
# Processing Record 9 of Set 18 | torbay
# Processing Record 10 of Set 18 | chuy
# Processing Record 11 of Set 18 | onalaska
# Processing Record 12 of Set 18 | kahului
# Processing Record 13 of Set 18 | bismarck
# Processing Record 14 of Set 18 | uniontown
# Processing Record 15 of Set 18 | portland
# Processing Record 16 of Set 18 | hailey
# Processing Record 17 of Set 18 | airai
# Processing Record 18 of Set 18 | new norfolk
# Processing Record 19 of Set 18 | kodiak
# Processing Record 20 of Set 18 | songling
# Processing Record 21 of Set 18 | murgab
# Processing Record 22 of Set 18 | dunedin
# Processing Record 23 of Set 18 | honiara
# Processing Record 24 of Set 18 | turukhansk
# Processing Record 25 of Set 18 | hermanus
# Processing Record 26 of Set 18 | weligama
# Processing Record 27 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 18 | burnie
# Processing Record 29 of Set 18 | kysyl-syr
# Processing Record 30 of Set 18 | dubti
# Processing Record 31 of Set 18 | straumen
# Processing Record 32 of Set 18 | san cristobal
# Processing Record 33 of Set 18 | kimbe
# Processing Record 34 of Set 18 | haimen
# Processing Record 35 of Set 18 | tuktoyaktuk
# Processing Record 36 of Set 18 | moindou
# Processing Record 37 of Set 18 | margate
# Processing Record 38 of Set 18 | dikson
# Processing Record 39 of Set 18 | santa cruz
# Processing Record 40 of Set 18 | itambacuri
# Processing Record 41 of Set 18 | krasnoselkup
# Processing Record 42 of Set 18 | cayenne
# Processing Record 43 of Set 18 | mengcheng
# Processing Record 44 of Set 18 | bambous virieux
# Processing Record 45 of Set 18 | belle fourche
# Processing Record 46 of Set 18 | sobolevo
# Processing Record 47 of Set 18 | arraial do cabo
# Processing Record 48 of Set 18 | linshu
# City not found. Skipping...
# Processing Record 49 of Set 18 | katsuura
# Processing Record 50 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 19 | dingzhou
# Processing Record 2 of Set 19 | brownwood
# Processing Record 3 of Set 19 | mundo nuevo
# Processing Record 4 of Set 19 | vila velha
# Processing Record 5 of Set 19 | tasiilaq
# Processing Record 6 of Set 19 | hithadhoo
# Processing Record 7 of Set 19 | broken hill
# Processing Record 8 of Set 19 | natal
# Processing Record 9 of Set 19 | evensk
# Processing Record 10 of Set 19 | safaga
# Processing Record 11 of Set 19 | rio brilhante
# Processing Record 12 of Set 19 | conway
# Processing Record 13 of Set 19 | vila franca do campo
# Processing Record 14 of Set 19 | port shepstone
# Processing Record 15 of Set 19 | tutoia
# Processing Record 16 of Set 19 | williston
# Processing Record 17 of Set 19 | sicamous
# Processing Record 18 of Set 19 | alberton
# Processing Record 19 of Set 19 | georgetown
# Processing Record 20 of Set 19 | saskylakh
# Processing Record 21 of Set 19 | shalinskoye
# Processing Record 22 of Set 19 | auki
# Processing Record 23 of Set 19 | shingu
# Processing Record 24 of Set 19 | nome
# Processing Record 25 of Set 19 | brae
# Processing Record 26 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 19 | coahuayana
# Processing Record 28 of Set 19 | darnah
# Processing Record 29 of Set 19 | wilmington
# Processing Record 30 of Set 19 | berlevag
# Processing Record 31 of Set 19 | dongsheng
# Processing Record 32 of Set 19 | olafsvik
# Processing Record 33 of Set 19 | balotra
# Processing Record 34 of Set 19 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 19 | channel-port aux basques
# Processing Record 36 of Set 19 | kon tum
# Processing Record 37 of Set 19 | vestmannaeyjar
# Processing Record 38 of Set 19 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 19 | clyde river
# Processing Record 40 of Set 19 | cherskiy
# Processing Record 41 of Set 19 | calabar
# Processing Record 42 of Set 19 | kununurra
# Processing Record 43 of Set 19 | datong
# Processing Record 44 of Set 19 | fairbanks
# Processing Record 45 of Set 19 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 19 | san patricio
# Processing Record 47 of Set 19 | halifax
# Processing Record 48 of Set 19 | kijang
# Processing Record 49 of Set 19 | pedernales
# Processing Record 50 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 20 | bilibino
# Processing Record 2 of Set 20 | lahat
# Processing Record 3 of Set 20 | hauterive
# Processing Record 4 of Set 20 | sao gabriel
# Processing Record 5 of Set 20 | karratha
# Processing Record 6 of Set 20 | namatanai
# Processing Record 7 of Set 20 | eureka
# Processing Record 8 of Set 20 | adrar
# Processing Record 9 of Set 20 | bruchkobel
# Processing Record 10 of Set 20 | zatoka
# Processing Record 11 of Set 20 | trincomalee
# Processing Record 12 of Set 20 | north myrtle beach
# Processing Record 13 of Set 20 | laguna
# Processing Record 14 of Set 20 | sao jose da coroa grande
# Processing Record 15 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 20 | iquique
# Processing Record 17 of Set 20 | ballina
# Processing Record 18 of Set 20 | gangawati
# Processing Record 19 of Set 20 | lannion
# Processing Record 20 of Set 20 | nabire
# Processing Record 21 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 20 | cidreira
# Processing Record 23 of Set 20 | mananjary
# Processing Record 24 of Set 20 | vardo
# Processing Record 25 of Set 20 | norman wells
# Processing Record 26 of Set 20 | fayaoue
# Processing Record 27 of Set 20 | takoradi
# Processing Record 28 of Set 20 | jamame
# Processing Record 29 of Set 20 | marsh harbour
# Processing Record 30 of Set 20 | shambu
# Processing Record 31 of Set 20 | gambela
# Processing Record 32 of Set 20 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 20 | naze
# Processing Record 34 of Set 20 | tiarei
# Processing Record 35 of Set 20 | itoman
# Processing Record 36 of Set 20 | vyshhorod
# Processing Record 37 of Set 20 | chaozhou
# Processing Record 38 of Set 20 | antalaha
# Processing Record 39 of Set 20 | acapulco
# Processing Record 40 of Set 20 | vostok
# Processing Record 41 of Set 20 | comodoro rivadavia
# Processing Record 42 of Set 20 | east london
# Processing Record 43 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 20 | kampot
# Processing Record 45 of Set 20 | gopalpur
# Processing Record 46 of Set 20 | north bend
# Processing Record 47 of Set 20 | talcahuano
# Processing Record 48 of Set 20 | piryion
# City not found. Skipping...
# Processing Record 49 of Set 20 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 20 | muros
# Processing Record 1 of Set 21 | erzin
# Processing Record 2 of Set 21 | fort smith
# Processing Record 3 of Set 21 | ngunguru
# Processing Record 4 of Set 21 | adilcevaz
# Processing Record 5 of Set 21 | khandyga
# Processing Record 6 of Set 21 | chicama
# Processing Record 7 of Set 21 | huanren
# Processing Record 8 of Set 21 | boa vista
# Processing Record 9 of Set 21 | stony plain
# Processing Record 10 of Set 21 | bandarbeyla
# Processing Record 11 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 21 | loa janan
# Processing Record 13 of Set 21 | kirakira
# Processing Record 14 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 21 | portree
# Processing Record 16 of Set 21 | hasaki
# Processing Record 17 of Set 21 | codrington
# Processing Record 18 of Set 21 | innisfail
# Processing Record 19 of Set 21 | catamarca
# Processing Record 20 of Set 21 | mahenge
# Processing Record 21 of Set 21 | fort frances
# Processing Record 22 of Set 21 | biak
# Processing Record 23 of Set 21 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 24 of Set 21 | bengkulu
# Processing Record 25 of Set 21 | pitimbu
# Processing Record 26 of Set 21 | tawnat
# City not found. Skipping...
# Processing Record 27 of Set 21 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 21 | son tay
# Processing Record 29 of Set 21 | ardesen
# Processing Record 30 of Set 21 | amurzet
# Processing Record 31 of Set 21 | palauig
# Processing Record 32 of Set 21 | miramar
# Processing Record 33 of Set 21 | upernavik
# Processing Record 34 of Set 21 | camacha
# Processing Record 35 of Set 21 | caraballeda
# Processing Record 36 of Set 21 | kasongo-lunda
# Processing Record 37 of Set 21 | marzuq
# Processing Record 38 of Set 21 | orotukan
# Processing Record 39 of Set 21 | tupik
# Processing Record 40 of Set 21 | jining
# Processing Record 41 of Set 21 | namibe
# Processing Record 42 of Set 21 | constitucion
# Processing Record 43 of Set 21 | salalah
# Processing Record 44 of Set 21 | moirang
# Processing Record 45 of Set 21 | mazamari
# Processing Record 46 of Set 21 | tongchuan
# Processing Record 47 of Set 21 | paracatu
# Processing Record 48 of Set 21 | kalmunai
# Processing Record 49 of Set 21 | bathsheba
# Processing Record 50 of Set 21 | penzance
# Processing Record 1 of Set 22 | ivdel
# Processing Record 2 of Set 22 | sur
# Processing Record 3 of Set 22 | port-gentil
# Processing Record 4 of Set 22 | denizli
# Processing Record 5 of Set 22 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 22 | wylie
# Processing Record 7 of Set 22 | carlisle
# Processing Record 8 of Set 22 | remedios
# Processing Record 9 of Set 22 | mayo
# Processing Record 10 of Set 22 | pundaguitan
# Processing Record 11 of Set 22 | san miguel
# Processing Record 12 of Set 22 | souillac
# Processing Record 13 of Set 22 | flin flon
# Processing Record 14 of Set 22 | lichinga
# Processing Record 15 of Set 22 | nanortalik
# Processing Record 16 of Set 22 | puri
# Processing Record 17 of Set 22 | paraopeba
# Processing Record 18 of Set 22 | talnakh
# Processing Record 19 of Set 22 | monroe
# Processing Record 20 of Set 22 | balkhash
# Processing Record 21 of Set 22 | sovetskiy
# Processing Record 22 of Set 22 | tautira
# Processing Record 23 of Set 22 | minyar
# Processing Record 24 of Set 22 | saint anthony
# Processing Record 25 of Set 22 | yeppoon
# Processing Record 26 of Set 22 | kraksaan
# Processing Record 27 of Set 22 | tuatapere
# Processing Record 28 of Set 22 | amazar
# Processing Record 29 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 22 | changji
# Processing Record 31 of Set 22 | jaggayyapeta
# Processing Record 32 of Set 22 | gaoua
# Processing Record 33 of Set 22 | subaytilah
# City not found. Skipping...
# Processing Record 34 of Set 22 | charyshskoye
# Processing Record 35 of Set 22 | dingle
# Processing Record 36 of Set 22 | yuzhou
# Processing Record 37 of Set 22 | kailua
# Processing Record 38 of Set 22 | srednekolymsk
# Processing Record 39 of Set 22 | oxford
# Processing Record 40 of Set 22 | islahiye
# Processing Record 41 of Set 22 | byron bay
# Processing Record 42 of Set 22 | kadyy
# Processing Record 43 of Set 22 | sakakah
# Processing Record 44 of Set 22 | hudiksvall
# Processing Record 45 of Set 22 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 22 | zaysan
# Processing Record 47 of Set 22 | las rosas
# Processing Record 48 of Set 22 | bonavista
# Processing Record 49 of Set 22 | ugoofaaru
# Processing Record 50 of Set 22 | port hardy
# Processing Record 1 of Set 23 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 23 | pakxan
# Processing Record 3 of Set 23 | balikpapan
# Processing Record 4 of Set 23 | gat
# Processing Record 5 of Set 23 | caliling
# Processing Record 6 of Set 23 | areal
# Processing Record 7 of Set 23 | brigantine
# Processing Record 8 of Set 23 | buchanan
# Processing Record 9 of Set 23 | japura
# Processing Record 10 of Set 23 | mulege
# Processing Record 11 of Set 23 | rawson
# Processing Record 12 of Set 23 | ponta do sol
# Processing Record 13 of Set 23 | kiunga
# Processing Record 14 of Set 23 | masvingo
# Processing Record 15 of Set 23 | mahon
# Processing Record 16 of Set 23 | plettenberg bay
# Processing Record 17 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 23 | rio gallegos
# Processing Record 19 of Set 23 | dukat
# Processing Record 20 of Set 23 | narsaq
# Processing Record 21 of Set 23 | barrow
# Processing Record 22 of Set 23 | egvekinot
# Processing Record 23 of Set 23 | pelym
# Processing Record 24 of Set 23 | araouane
# Processing Record 25 of Set 23 | navadwip
# Processing Record 26 of Set 23 | okmulgee
# Processing Record 27 of Set 23 | college
# Processing Record 28 of Set 23 | iralaya
# Processing Record 29 of Set 23 | saint-augustin
# Processing Record 30 of Set 23 | taua
# Processing Record 31 of Set 23 | orissaare
# Processing Record 32 of Set 23 | quatre cocos
# Processing Record 33 of Set 23 | almaznyy
# Processing Record 34 of Set 23 | ilulissat
# Processing Record 35 of Set 23 | vyritsa
# Processing Record 36 of Set 23 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 23 | inuvik
# Processing Record 38 of Set 23 | sitka
# Processing Record 39 of Set 23 | sangar
# Processing Record 40 of Set 23 | sechura
# Processing Record 41 of Set 23 | dubbo
# Processing Record 42 of Set 23 | lavrentiya
# Processing Record 43 of Set 23 | hede
# Processing Record 44 of Set 23 | katherine
# Processing Record 45 of Set 23 | goba
# Processing Record 46 of Set 23 | luanda
# Processing Record 47 of Set 23 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 23 | klaksvik
# Processing Record 49 of Set 23 | batagay-alyta
# Processing Record 50 of Set 23 | grand gaube
# Processing Record 1 of Set 24 | ipixuna
# Processing Record 2 of Set 24 | kati
# Processing Record 3 of Set 24 | bend
# Processing Record 4 of Set 24 | deqing
# Processing Record 5 of Set 24 | khani
# Processing Record 6 of Set 24 | san quintin
# Processing Record 7 of Set 24 | yulara
# Processing Record 8 of Set 24 | maryanovka
# City not found. Skipping...
# Processing Record 9 of Set 24 | havoysund
# Processing Record 10 of Set 24 | kieta
# Processing Record 11 of Set 24 | hobyo
# Processing Record 12 of Set 24 | arica
# Processing Record 13 of Set 24 | wadi maliz
# Processing Record 14 of Set 24 | hovd
# Processing Record 15 of Set 24 | te anau
# Processing Record 16 of Set 24 | lasa
# Processing Record 17 of Set 24 | mocuba
# Processing Record 18 of Set 24 | praia da vitoria
# Processing Record 19 of Set 24 | siilinjarvi
# Processing Record 20 of Set 24 | hambantota
# Processing Record 21 of Set 24 | lodja
# Processing Record 22 of Set 24 | cruz alta
# Processing Record 23 of Set 24 | blonduos
# City not found. Skipping...
# Processing Record 24 of Set 24 | kerchevskiy
# Processing Record 25 of Set 24 | buritizeiro
# Processing Record 26 of Set 24 | bethel
# Processing Record 27 of Set 24 | jambi
# Processing Record 28 of Set 24 | belmonte
# Processing Record 29 of Set 24 | esperance
# Processing Record 30 of Set 24 | yurla
# Processing Record 31 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 24 | burhanpur
# Processing Record 33 of Set 24 | phrae
# Processing Record 34 of Set 24 | port macquarie
# Processing Record 35 of Set 24 | jeremie
# Processing Record 36 of Set 24 | svetlaya
# Processing Record 37 of Set 24 | huntington
# Processing Record 38 of Set 24 | malkangiri
# Processing Record 39 of Set 24 | central point
# Processing Record 40 of Set 24 | monatele
# City not found. Skipping...
# Processing Record 41 of Set 24 | mount isa
# Processing Record 42 of Set 24 | progreso
# Processing Record 43 of Set 24 | nikolskoye
# Processing Record 44 of Set 24 | bodden town
# Processing Record 45 of Set 24 | platanos
# Processing Record 46 of Set 24 | lambarene
# Processing Record 47 of Set 24 | touros
# Processing Record 48 of Set 24 | pacific grove
# Processing Record 49 of Set 24 | kenai
# Processing Record 50 of Set 24 | traverse city
# Processing Record 1 of Set 25 | komsomolskiy
# Processing Record 2 of Set 25 | lompoc
# Processing Record 3 of Set 25 | alhadas
# Processing Record 4 of Set 25 | ostrovnoy
# Processing Record 5 of Set 25 | nantucket
# Processing Record 6 of Set 25 | goianesia
# Processing Record 7 of Set 25 | kalakamati
# Processing Record 8 of Set 25 | andenes
# Processing Record 9 of Set 25 | manokwari
# Processing Record 10 of Set 25 | conceicao do almeida
# Processing Record 11 of Set 25 | obihiro
# Processing Record 12 of Set 25 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 25 | yining
# Processing Record 14 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 25 | liwale
# Processing Record 16 of Set 25 | alekseyevsk
# Processing Record 17 of Set 25 | laiya
# Processing Record 18 of Set 25 | meulaboh
# Processing Record 19 of Set 25 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 25 | foki
# Processing Record 21 of Set 25 | galgani
# City not found. Skipping...
# Processing Record 22 of Set 25 | vasterhaninge
# Processing Record 23 of Set 25 | smidovich
# Processing Record 24 of Set 25 | port alberni
# Processing Record 25 of Set 25 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 25 | praia
# Processing Record 27 of Set 25 | jatai
# Processing Record 28 of Set 25 | saldanha
# Processing Record 29 of Set 25 | magway
# Processing Record 30 of Set 25 | nelson bay
# Processing Record 31 of Set 25 | cumberland
# Processing Record 32 of Set 25 | masallatah
# Processing Record 33 of Set 25 | nemuro
# Processing Record 34 of Set 25 | juli
# Processing Record 35 of Set 25 | muzquiz
# City not found. Skipping...
# Processing Record 36 of Set 25 | qandala
# Processing Record 37 of Set 25 | gloucester
# Processing Record 38 of Set 25 | uray
# Processing Record 39 of Set 25 | tartagal
# Processing Record 40 of Set 25 | los andes
# Processing Record 41 of Set 25 | syasstroy
# Processing Record 42 of Set 25 | gornyak
# Processing Record 43 of Set 25 | matagami
# Processing Record 44 of Set 25 | ochamchira
# Processing Record 45 of Set 25 | katima mulilo
# Processing Record 46 of Set 25 | rongcheng
# Processing Record 47 of Set 25 | opuwo
# Processing Record 48 of Set 25 | dedza
# Processing Record 49 of Set 25 | hofn
# Processing Record 50 of Set 25 | diamantino
# Processing Record 1 of Set 26 | coquimbo
# Processing Record 2 of Set 26 | winnemucca
# Processing Record 3 of Set 26 | pathein
# Processing Record 4 of Set 26 | wajima
# Processing Record 5 of Set 26 | saurimo
# Processing Record 6 of Set 26 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 26 | general roca
# Processing Record 8 of Set 26 | baykit
# Processing Record 9 of Set 26 | yendi
# Processing Record 10 of Set 26 | kokopo
# Processing Record 11 of Set 26 | kisangani
# Processing Record 12 of Set 26 | akureyri
# Processing Record 13 of Set 26 | lensk
# Processing Record 14 of Set 26 | lengshuitan
# Processing Record 15 of Set 26 | arlit
# Processing Record 16 of Set 26 | tabou
# Processing Record 17 of Set 26 | isangel
# Processing Record 18 of Set 26 | addis zemen
# City not found. Skipping...
# Processing Record 19 of Set 26 | palatka
# Processing Record 20 of Set 26 | zaozerne
# Processing Record 21 of Set 26 | cherrapunji
# Processing Record 22 of Set 26 | socorro
# Processing Record 23 of Set 26 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 26 | sayyan
# Processing Record 25 of Set 26 | dudinka
# Processing Record 26 of Set 26 | hamilton
# Processing Record 27 of Set 26 | inhambane
# Processing Record 28 of Set 26 | makasar
# Processing Record 29 of Set 26 | ewa beach
# Processing Record 30 of Set 26 | borgo san dalmazzo
# Processing Record 31 of Set 26 | ures
# Processing Record 32 of Set 26 | bela
# Processing Record 33 of Set 26 | gurlan
# Processing Record 34 of Set 26 | kavaratti
# Processing Record 35 of Set 26 | road town
# Processing Record 36 of Set 26 | agadir
# Processing Record 37 of Set 26 | makakilo city
# Processing Record 38 of Set 26 | janauba
# Processing Record 39 of Set 26 | vao
# Processing Record 40 of Set 26 | yumen
# Processing Record 41 of Set 26 | whyalla
# Processing Record 42 of Set 26 | roald
# Processing Record 43 of Set 26 | bubaque
# Processing Record 44 of Set 26 | bardiyah
# Processing Record 45 of Set 26 | konstantinovka
# Processing Record 46 of Set 26 | tecoanapa
# Processing Record 47 of Set 26 | ridgecrest
# Processing Record 48 of Set 26 | mecca
# Processing Record 49 of Set 26 | camopi
# Processing Record 50 of Set 26 | faya
# Processing Record 1 of Set 27 | tezu
# Processing Record 2 of Set 27 | jiuquan
# Processing Record 3 of Set 27 | chimbote
# Processing Record 4 of Set 27 | merauke
# Processing Record 5 of Set 27 | padang
# Processing Record 6 of Set 27 | batemans bay
# Processing Record 7 of Set 27 | elko
# Processing Record 8 of Set 27 | nchelenge
# Processing Record 9 of Set 27 | okha
# Processing Record 10 of Set 27 | nuevo progreso
# Processing Record 11 of Set 27 | nouadhibou
# Processing Record 12 of Set 27 | fernandopolis
# Processing Record 13 of Set 27 | vermillion
# Processing Record 14 of Set 27 | puerto baquerizo moreno
# Processing Record 15 of Set 27 | vangaindrano
# Processing Record 16 of Set 27 | karlskrona
# Processing Record 17 of Set 27 | nago
# Processing Record 18 of Set 27 | gandu
# Processing Record 19 of Set 27 | okhotsk
# Processing Record 20 of Set 27 | raudeberg
# Processing Record 21 of Set 27 | mitla
# Processing Record 22 of Set 27 | ambon
# Processing Record 23 of Set 27 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 27 | ketchikan
# Processing Record 25 of Set 27 | yuryev-polskiy
# Processing Record 26 of Set 27 | tamugan
# Processing Record 27 of Set 27 | goderich
# Processing Record 28 of Set 27 | kingsland
# Processing Record 29 of Set 27 | garachine
# Processing Record 30 of Set 27 | iqaluit
# Processing Record 31 of Set 27 | ulaanbaatar
# Processing Record 32 of Set 27 | aswan
# Processing Record 33 of Set 27 | leshukonskoye
# Processing Record 34 of Set 27 | serenje
# Processing Record 35 of Set 27 | gorontalo
# Processing Record 36 of Set 27 | kumluca
# Processing Record 37 of Set 27 | plouzane
# Processing Record 38 of Set 27 | buraydah
# Processing Record 39 of Set 27 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 27 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 41 of Set 27 | guerrero negro
# Processing Record 42 of Set 27 | nizwa
# Processing Record 43 of Set 27 | tyler
# Processing Record 44 of Set 27 | loiza
# Processing Record 45 of Set 27 | zakharovo
# Processing Record 46 of Set 27 | usinsk
# Processing Record 47 of Set 27 | marovoay
# Processing Record 48 of Set 27 | riyadh
# Processing Record 49 of Set 27 | cururupu
# Processing Record 50 of Set 27 | jibuti
# Processing Record 1 of Set 28 | thaba-tseka
# Processing Record 2 of Set 28 | kaeo
# Processing Record 3 of Set 28 | la rioja
# Processing Record 4 of Set 28 | pailon
# Processing Record 5 of Set 28 | taoudenni
# Processing Record 6 of Set 28 | havre-saint-pierre
# Processing Record 7 of Set 28 | zempoala
# Processing Record 8 of Set 28 | pandan
# Processing Record 9 of Set 28 | achisay
# City not found. Skipping...
# Processing Record 10 of Set 28 | tommot
# Processing Record 11 of Set 28 | hillsborough
# Processing Record 12 of Set 28 | cap malheureux
# Processing Record 13 of Set 28 | tateyama
# Processing Record 14 of Set 28 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 28 | kavant
# City not found. Skipping...
# Processing Record 16 of Set 28 | jacqueville
# Processing Record 17 of Set 28 | two rivers
# Processing Record 18 of Set 28 | lorengau
# Processing Record 19 of Set 28 | awka
# Processing Record 20 of Set 28 | the pas
# Processing Record 21 of Set 28 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 28 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 28 | paamiut
# Processing Record 24 of Set 28 | dali
# Processing Record 25 of Set 28 | bouca
# Processing Record 26 of Set 28 | omboue
# Processing Record 27 of Set 28 | athabasca
# Processing Record 28 of Set 28 | tura
# Processing Record 29 of Set 28 | catia la mar
# Processing Record 30 of Set 28 | san carlos de bariloche
# Processing Record 31 of Set 28 | northallerton
# Processing Record 32 of Set 28 | keshabpur
# Processing Record 33 of Set 28 | trelew
# Processing Record 34 of Set 28 | mumford
# Processing Record 35 of Set 28 | bloomfield
# Processing Record 36 of Set 28 | vanavara
# Processing Record 37 of Set 28 | robertsport
# Processing Record 38 of Set 28 | iranshahr
# Processing Record 39 of Set 28 | ankazoabo
# Processing Record 40 of Set 28 | puerto leguizamo
# Processing Record 41 of Set 28 | grants pass
# Processing Record 42 of Set 28 | solnechnyy
# Processing Record 43 of Set 28 | timiryazevskoye
# Processing Record 44 of Set 28 | eyl
# Processing Record 45 of Set 28 | feni
# Processing Record 46 of Set 28 | jobat
# Processing Record 47 of Set 28 | monrovia
# Processing Record 48 of Set 28 | ahipara
# Processing Record 49 of Set 28 | bolu
# Processing Record 50 of Set 28 | djambala
# Processing Record 1 of Set 29 | maltahohe
# Processing Record 2 of Set 29 | bhusawal
# Processing Record 3 of Set 29 | tambun
# Processing Record 4 of Set 29 | broome
# Processing Record 5 of Set 29 | srikakulam
# Processing Record 6 of Set 29 | high level
# Processing Record 7 of Set 29 | tete
# Processing Record 8 of Set 29 | huarmey
# Processing Record 9 of Set 29 | sibu
# Processing Record 10 of Set 29 | marang
# Processing Record 11 of Set 29 | zhukovka
# Processing Record 12 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 29 | barcelona
# Processing Record 14 of Set 29 | ambilobe
# Processing Record 15 of Set 29 | havelock
# Processing Record 16 of Set 29 | tarakan
# Processing Record 17 of Set 29 | horsham
# Processing Record 18 of Set 29 | portlethen
# Processing Record 19 of Set 29 | moa
# Processing Record 20 of Set 29 | shagonar
# Processing Record 21 of Set 29 | abnub
# Processing Record 22 of Set 29 | suntar
# Processing Record 23 of Set 29 | nichinan
# Processing Record 24 of Set 29 | korla
# Processing Record 25 of Set 29 | termoli
# Processing Record 26 of Set 29 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 29 | clarksburg
# Processing Record 28 of Set 29 | nyurba
# Processing Record 29 of Set 29 | soure
# Processing Record 30 of Set 29 | rudbar
# Processing Record 31 of Set 29 | monte alegre de minas
# Processing Record 32 of Set 29 | pozo colorado
# Processing Record 33 of Set 29 | capinzal
# Processing Record 34 of Set 29 | phnum penh
# City not found. Skipping...
# Processing Record 35 of Set 29 | ouargaye
# Processing Record 36 of Set 29 | matameye
# City not found. Skipping...
# Processing Record 37 of Set 29 | san fernando
# Processing Record 38 of Set 29 | kudahuvadhoo
# Processing Record 39 of Set 29 | vuktyl
# Processing Record 40 of Set 29 | henties bay
# Processing Record 41 of Set 29 | vanimo
# Processing Record 42 of Set 29 | waling
# Processing Record 43 of Set 29 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 29 | nishihara
# Processing Record 45 of Set 29 | adeje
# Processing Record 46 of Set 29 | mount gambier
# Processing Record 47 of Set 29 | hami
# Processing Record 48 of Set 29 | culaman
# Processing Record 49 of Set 29 | mul
# Processing Record 50 of Set 29 | mitsamiouli
# Processing Record 1 of Set 30 | berdyuzhye
# City not found. Skipping...
# Processing Record 2 of Set 30 | sukpak
# Processing Record 3 of Set 30 | pokrovskoye
# Processing Record 4 of Set 30 | pangody
# Processing Record 5 of Set 30 | helong
# Processing Record 6 of Set 30 | sao pedro do sul
# Processing Record 7 of Set 30 | miri
# Processing Record 8 of Set 30 | destin
# Processing Record 9 of Set 30 | healdsburg
# Processing Record 10 of Set 30 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 30 | miami springs
# Processing Record 12 of Set 30 | beringovskiy
# Processing Record 13 of Set 30 | kruisfontein
# Processing Record 14 of Set 30 | iida
# Processing Record 15 of Set 30 | estreito
# Processing Record 16 of Set 30 | alofi
# Processing Record 17 of Set 30 | ust-nera
# Processing Record 18 of Set 30 | olinda
# Processing Record 19 of Set 30 | bukachacha
# Processing Record 20 of Set 30 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 30 | yaan
# Processing Record 22 of Set 30 | alta floresta
# Processing Record 23 of Set 30 | mabaruma
# Processing Record 24 of Set 30 | pemangkat
# Processing Record 25 of Set 30 | puerto quijarro
# Processing Record 26 of Set 30 | gongzhuling
# Processing Record 27 of Set 30 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 30 | lagoa
# Processing Record 29 of Set 30 | san blas
# Processing Record 30 of Set 30 | luderitz
# Processing Record 31 of Set 30 | oussouye
# Processing Record 32 of Set 30 | xuanhua
# Processing Record 33 of Set 30 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 30 | lata
# Processing Record 35 of Set 30 | samagaltay
# Processing Record 36 of Set 30 | geresk
# City not found. Skipping...
# Processing Record 37 of Set 30 | gisborne
# Processing Record 38 of Set 30 | samfya
# Processing Record 39 of Set 30 | anapskaya
# Processing Record 40 of Set 30 | lithgow
# Processing Record 41 of Set 30 | horasan
# Processing Record 42 of Set 30 | nara
# Processing Record 43 of Set 30 | rapid valley
# Processing Record 44 of Set 30 | la ronge
# Processing Record 45 of Set 30 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 30 | sinnamary
# Processing Record 47 of Set 30 | deputatskiy
# Processing Record 48 of Set 30 | galesong
# Processing Record 49 of Set 30 | xenia
# Processing Record 50 of Set 30 | cazanesti
# Processing Record 1 of Set 31 | kedgwick
# Processing Record 2 of Set 31 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 31 | ambovombe
# Processing Record 4 of Set 31 | dalvik
# Processing Record 5 of Set 31 | nicoya
# Processing Record 6 of Set 31 | porto novo
# Processing Record 7 of Set 31 | bocaranga
# City not found. Skipping...
# Processing Record 8 of Set 31 | umm lajj
# Processing Record 9 of Set 31 | mangrul pir
# Processing Record 10 of Set 31 | kutum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ossora      RU  59.2353  163.0719     47.08        93         100
# 1  Puerto Ayora      EC  -0.7393  -90.3518     71.55        92          40
# 2        Castro      BR -24.7911  -50.0119     58.80        70          82
# 3   Yellowknife      CA  62.4560 -114.3525     57.72        72          40
# 4       Biltine      TD  14.5333   20.9167    102.13        19          11
# 5       Fortuna      US  40.5982 -124.1573     55.92        75          90
# 6        Igunga      TZ  -4.2833   33.8833     86.74        21           1
# 7         Vaini      TO -21.2000 -175.2000     71.76        78          40
# 8   Keti Bandar      PK  24.1447   67.4497     87.37        65          14
# 9       Gravdal      NO  68.1214   13.5031     55.29        71          40
#
#    Wind Speed Current Description
# 0        3.89          light rain
# 1        1.99    scattered clouds
# 2        7.31       broken clouds
# 3        6.91    scattered clouds
# 4        8.97          few clouds
# 5        0.00     overcast clouds
# 6        6.20           clear sky
# 7       11.50    scattered clouds
# 8       18.39          few clouds
# 9       11.50    scattered clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
